# %%
import pandas as pd
import numpy as np

df= pd.read_excel("C:/Users/DIPPAL/Documents/Data Analysis Traineeship/Task 1/customers-1000.xlsx")

# %%
df.head()
df.info()

print("Shape : ",df.shape)
print("Missing values",df.isnull().sum())
print("Duplicates Values",df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              1000 non-null   int64
#  1   Customer Id        1000 non-null   object
#  2   First Name         1000 non-null   object
#  3   Last Name          1000 non-null   object
#  4   Company            1000 non-null   object
#  5   City               1000 non-null   object
#  6   Country            1000 non-null   object
#  7   Phone 1            1000 non-null   object
#  8   Phone 2            1000 non-null   object
#  9   Email              1000 non-null   object
#  10  Subscription Date  1000 non-null   datetime64[ns]
#  11  Website            1000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 93.9+ KB
# Shape :  (1000, 12)
# Missing values Index                0
# Customer Id          0
# First Name           0
# ...

# %%
df = df.drop_duplicates()

# %%
print("Total duplicates:", df.duplicated().sum())
# Out:
# Total duplicates: 0

# %%
df= df.drop(columns=["temp_id","notes"],errors='ignore')

# %%
df.columns = df.columns.str.replace("_", "", regex=False)
df.columns = df.columns.str.replace(" ", "_").str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Index', 'CustomerId', 'FirstName', 'LastName', 'Company', 'City', 'Country', 'Phone1', 'Phone2', 'Email', 'SubscriptionDate', 'Website']

# %%
#df.columns = df.columns.str.strip().str.replace("","_")
df["Email"] = df["Email"].str.strip().str.lower()
df["Country"] = df["Country"].str.strip().str.title()

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

df
# Out:
#      Index      Customer Id   First Name    Last Name  \
# 0        1  dE014d010c7ab0c       Andrew      Goodman
# 1        2  2B54172c8b65eC3        Alvin         Lane
# 2        3  d794Dd48988d2ac        Jenna      Harding
# 3        4  3b3Aa4aCc68f3Be     Fernando         Ford
# 4        5  D60df62ad2ae41E         Kara        Woods
# 5        6  8aaa5d0CE9ee311      Marissa       Gamble
# 6        7  73B22Ac8A43DD1A        Julie       Cooley
# 7        8  DC94CCd993D311b       Lauren        Villa
# 8        9  9Ba746Cb790FED9        Emily       Bryant
# 9       10  aAa1EDfaA70DA0c        Marie      Estrada
# 10      11  bf104C25d0BA4E1      Nichole       Cannon
# 11      12  bf2fA37cbAd7dDc      Bernard       Ritter
# 12      13  4fa8ffcdBbf53bB       Darryl       Archer
# 13      14  aBd960429ecd363         Ryan           Li
# 14      15  2a0c691Ce19C6f3        Vicki        Nunez
# 15      16  B58fecf82f997Dd         Sean     Townsend
# ...

# %%
df = df.drop(columns=["Index", "Phone_2", "Website"], errors='ignore')

# %%
df["Country"].value_counts()
df["City"].value_counts().head(10)
# Out:
# City
# Port Gavin       2
# Lake Dwayne      2
# Tommyshire       2
# New Yolanda      2
# South Roberta    2
# Lake Douglas     2
# East Wendy       2
# Berrymouth       2
# New Samantha     2
# Coxburgh         2
# Name: count, dtype: int64

# %%
df = df.drop(columns=["Index", "Phone 2", "Website"], errors='ignore')

# %%
#df.dtypes
df.info()
df.head()
print("Duplicates:", df.duplicated().sum())
print("Shape:", df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer Id        1000 non-null   object
#  1   First Name         1000 non-null   object
#  2   Last Name          1000 non-null   object
#  3   Company            1000 non-null   object
#  4   City               1000 non-null   object
#  5   Country            1000 non-null   object
#  6   Phone 1            1000 non-null   object
#  7   Email              1000 non-null   object
#  8   Subscription Date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(8)
# memory usage: 70.4+ KB
# Duplicates: 0
# Shape: (1000, 9)

# %%
df.to_csv("C:/Users/DIPPAL/Documents/Data Analysis Traineeship/Task 1/ cleaned_sales_data.csv",index=False)
